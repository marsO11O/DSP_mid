# %%
import thinkdsp as td
import thinkdsp
import matplotlib.pyplot as plt
x= td.UncorrelatedGaussianNoise()
x= x.make_wave(duration= 1, framerate= 10000)
x.ts, x.ys
x.ys.shape
# Out:
# (10000,)

# %%
from thinkdsp import UncorrelatedGaussianNoise

signal = UncorrelatedGaussianNoise()
x = signal.make_wave(duration=0.5, framerate=11025)
x.plot(linewidth=0.5)

# %%
x.ys.max(), x.ys.mean(), x.ys.std()
# Out:
# (3.7245990019687825, 0.0006447491718403579, 0.9974281433829476)

# %%
spectrum = x.make_spectrum()
spectrum.plot_power(linewidth=1)

# %%
spectrum.plot()

# %%
spectrum.plot_power()

# %%
integ = spectrum.make_integrated_spectrum()
integ.plot_power()

# %%
integ.plot_power()
plt.xscale('log')
plt.yscale('log')
plt.grid(True)

# %%
y= thinkdsp.UncorrelatedGaussianNoise()

x= thinkdsp.UncorrelatedGaussianNoise()
x= x.make_wave(duration= 1, framerate= 10000)

y= x.cumsum()
x.ys.shape, y.ys.shape
y.plot()

# %%
plt.plot(x.ts, x.ys)

# %%
z= thinkdsp.BrownianNoise().make_wave(duration=1, framerate=10000)
z.plot()

# %%
z.make_spectrum().make_integrated_spectrum().estimate_slope()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-82fa107f3ce5> in <module>
# ----> 1 z.make_spectrum().make_integrated_spectrum().estimate_slope()
#
# ~\Anaconda3\lib\site-packages\thinkdsp.py in estimate_slope(self, low, high)
#     478         x = np.log(self.fs[low:high])
#     479         y = np.log(self.cs[low:high])
# --> 480         t = scipy.stats.linregress(x,y)
#     481         return t
#     482
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#      84
#      85     if x.size == 0 or y.size == 0:
# ---> 86         raise ValueError("Inputs must not be empty.")
#      87
#      88     n = len(x)
#
# ValueError: Inputs must not be empty.
